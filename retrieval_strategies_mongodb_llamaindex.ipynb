# %%
import warnings
import os
import logging
from urllib.parse import quote_plus
from dotenv import load_dotenv
from pymongo import MongoClient
from llama_index.llms.gemini import Gemini
from llama_index.core import Settings
import pandas as pd
import ast
from llama_index.core import Document
from llama_index.embeddings.google_genai import GoogleGenAIEmbedding
from google.genai.types import EmbedContentConfig
from llama_index.vector_stores.mongodb import MongoDBAtlasVectorSearch
from pymongo.operations import SearchIndexModel
from pymongo.errors import OperationFailure
from llama_index.core.vector_stores import (
    FilterCondition,
    FilterOperator,
    MetadataFilter,
    MetadataFilters,
)

logging.getLogger('llama_index').setLevel(logging.ERROR)
warnings.filterwarnings('ignore')
# Out:
# /home/narasima/miniconda3/envs/llamaindex/lib/python3.14/site-packages/llama_index/llms/gemini/base.py:21: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
load_dotenv()
password = quote_plus(os.getenv("MONGO_PASSWORD"))
mongoURL : str = f"mongodb+srv://{user}:{password}@movierecommendation.fknnvlc.mongodb.net/?appName=MovieRecommendation"

try:
    mongodb_client = MongoClient(mongoURL)
    mongodb_client.admin.command('ping')
    print("Successfully connected to MongoDB!")
except Exception as e:
    print(f"Connection failed: {e}")

Settings.llm = Gemini(
    model="models/gemini-2.5-flash-lite", 
    api_key=os.getenv("GOOGLE_API_KEY")
)
print("Success! Gemini is now configured.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 load_dotenv()
# ----> 2 password = quote_plus(os.getenv("MONGO_PASSWORD"))
#       3 mongoURL : str = f"mongodb+srv://{user}:{password}@movierecommendation.fknnvlc.mongodb.net/?appName=MovieRecommendation"
#       5 try:
#
# File ~/miniconda3/envs/llamaindex/lib/python3.14/urllib/parse.py:968, in quote_plus(string, safe, encoding, errors)
#     966 else:
#     967     space = b' '
# --> 968 string = quote(string, safe + space, encoding, errors)
#     969 return string.replace(' ', '+')
#
# File ~/miniconda3/envs/llamaindex/lib/python3.14/urllib/parse.py:952, in quote(string, safe, encoding, errors)
#     950     if errors is not None:
#     951         raise TypeError("quote() doesn't support 'errors' for bytes")
# --> 952 return quote_from_bytes(string, safe)
#
# ...

# %%
data_path = "./data/movies_with_embeddings.csv"
data = pd.read_csv(data_path) 
print(f"Loaded {len(data)} rows.")
# Out:
# Loaded 8584 rows.

# %%
def safe_eval(val):
    if isinstance(val, str) and val.startswith('['):
        try:
            return ast.literal_eval(val)
        except:
            return []
    return val if isinstance(val, list) else []

# %%
for col in ["embedding", "genres_list", "cast_list", "languages_list"]:
    if col in data.columns:
        data[col] = data[col].apply(safe_eval)

print("Building Documents...")

documents = [
    Document(
        text=row['combined_text'],
        embedding=row['embedding'],
        metadata={
            "title": row.get('title', 'Unknown'),
            "rating": row.get('rating', 0),
            "languages": row.get('languages_list', []),
            "genres": row.get('genres_list', [])
        }
    )
    for _, row in data.iterrows() 
]

print(f"Success! Created {len(documents)} documents efficiently.")
# Out:
# Building Documents...
# Success! Created 8584 documents efficiently.

# %%
documents[0].metadata
# Out:
# {'title': 'Toy Story',
#  'rating': 7.7,
#  'languages': ['English'],
#  'genres': ['Animation', 'Comedy', 'Family']}

# %%
print(f"Your CSV embedding size: {len(documents[0].embedding)}")
# Out:
# Your CSV embedding size: 3072

# %%
Settings.embed_model = GoogleGenAIEmbedding(
    model_name="gemini-embedding-001",
    embedding_config=EmbedContentConfig(output_dimensionality=3072)
)

# %%
try:
    vector_store = MongoDBAtlasVectorSearch(
        mongodb_client,
        db_name="movie_recommender",
        collection_name="movies",
        vector_index_name="vector_index",
        embedding_key="embedding"
    )
    print("Vector store is alive.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Vector store is alive.

# %%
storage_context = StorageContext.from_defaults(vector_store=vector_store)

print(f"Ingesting {len(documents)} documents into MongoDB...")
vector_store_index = VectorStoreIndex.from_documents(
    documents,
    storage_context=storage_context,
    show_progress=True
)

print("DATABASE LOADED. Everything is now in the cloud.")
# Out:
# Ingesting 8584 documents into MongoDB...
# Parsing nodes: 100%|██████████| 8584/8584 [00:02<00:00, 3166.40it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# Generating embeddings: 0it [00:00, ?it/s]
# DATABASE LOADED. Everything is now in the cloud.

# %%
collection = mongodb_client["movie_recommender"]["movies"]

# %%
if collection.count_documents({}) > 0:
    print(f"Found data in {'movies'}. Connecting to existing index...")
    vector_store_index = VectorStoreIndex.from_vector_store(
        vector_store
    )
else:
    print("Empty database. Starting the big upload...")
    storage_context = StorageContext.from_defaults(vector_store=vector_store)
    
    vector_store_index = VectorStoreIndex.from_documents(
        documents,
        storage_context=storage_context,
        show_progress=True
    )
    print("Ingestion complete! Your movies are now in the cloud.")
# Out:
# Found data in movies. Connecting to existing index...

# %%
vs_model = SearchIndexModel(
    definition={
        "fields": [
            {
                "type": "vector",
                "path": "embedding",
                "numDimensions": 3072,
                "similarity": "cosine",
            },
            {"type": "filter", "path": "metadata.rating"},
            {"type": "filter", "path": "metadata.languages"},
        ]
    },
    name="vector_index",
    type="vectorSearch",
)

# %%
fts_model = SearchIndexModel(
    definition={
        "mappings": {
            "dynamic": True
        }
    },
    name="fts_index",
    type="search",
)

# %%
for model in [vs_model, fts_model]:
    model_name = model.document.get("name")
    
    try:
        collection.create_search_index(model=model)
        print(f"Index creation started for: {model_name}")
    except OperationFailure:
        print(f"{model_name} already exists. Skipping.")
# Out:
# Index creation started for: vector_index
# Index creation started for: fts_index

# %%
query_engine = vector_store_index.as_query_engine(
    similarity_top_k=5,
    response_mode="compact"
)

my_question = "Recommend a movie about a heist that goes wrong, but it should be funny."

response = query_engine.query(my_question)

print(response)
# Out:
# "Lock, Stock and Two Smoking Barrels" is a film about a group of friends who attempt a heist to quickly earn money after a poker game goes awry. "Take the Money and Run" follows the life of an inept bank robber. "Raising Arizona" features a couple who get into trouble after kidnapping a baby. "Out of Sight" is about a criminal planning one last heist and a federal marshal.

# %%
def get_recommendations(query: str, mode: str = "default", **kwargs) -> None:
    query_engine = vector_store_index.as_query_engine(
        similarity_top_k=5, 
        vector_store_query_mode=mode, 
        **kwargs
    )
    
    print(f"\n--- Search Mode: {mode.upper()} | Query: '{query}' ---")
    
    response = query_engine.query(query)
    
    if not response.source_nodes:
        print("No movies found matching those criteria.")
        return

    for node in response.source_nodes:
        title = node.metadata.get("title", "Unknown Title")
        rating = node.metadata.get("rating", "N/A")
        score = node.score if node.score else 0.0
        
        print(f"⭐ {rating} | Score: {score:.4f} | {title}")

filters = MetadataFilters(
    filters=[
        MetadataFilter(key="rating", value=7.0, operator=FilterOperator.GT),
        MetadataFilter(key="languages", value="English", operator=FilterOperator.EQ),
    ],
    condition=FilterCondition.AND,
)

# %%
get_recommendations(query="Action movies about humans fighting machines", mode="default")

get_recommendations(query="Terminator", mode="text_search")

get_recommendations(query="Robots vs Humans", mode="hybrid", alpha=0.5)

get_recommendations(
    query="Futuristic war against AI", 
    mode="hybrid", 
    alpha=0.7, 
    filters=filters
)
# Out:
# --- Search Mode: DEFAULT | Query: 'Action movies about humans fighting machines' ---
# ⭐ 5.1 | Score: 0.8475 | Eve of Destruction
# ⭐ 3.9 | Score: 0.8448 | Solo
# ⭐ 7.4 | Score: 0.8446 | The Terminator
# ⭐ 7.1 | Score: 0.8444 | RoboCop
# ⭐ 5.9 | Score: 0.8381 | Terminator 3: Rise of the Machines
#
# --- Search Mode: TEXT_SEARCH | Query: 'Terminator' ---
# No movies found matching those criteria.
#
# --- Search Mode: HYBRID | Query: 'Robots vs Humans' ---
# ⭐ 3.7 | Score: 0.5000 | Robot Stories
# ⭐ 6.8 | Score: 0.2500 | A.I. Artificial Intelligence
# ⭐ 6.4 | Score: 0.1667 | Short Circuit
# ⭐ 3.9 | Score: 0.1250 | Solo
# ⭐ 5.1 | Score: 0.1000 | Eve of Destruction
#
# --- Search Mode: HYBRID | Query: 'Futuristic war against AI' ---
# ⭐ 7.9 | Score: 0.7000 | The Matrix
# ⭐ 7.4 | Score: 0.3500 | The Terminator
# ⭐ 7.9 | Score: 0.2333 | Full Metal Jacket
# ⭐ 7.1 | Score: 0.1750 | RoboCop
# ⭐ 7.9 | Score: 0.1400 | 2001: A Space Odyssey
